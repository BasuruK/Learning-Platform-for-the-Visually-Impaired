# %%
import skimage.data
import selectivesearch
from skimage import io
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import cv2
# %matplotlib inline

# %%
img = io.imread('C:/Users/Basuru Kusal/Pictures/Camera Roll/lon.jpg')
img_lbl, regions = selectivesearch.selective_search(img, scale=1000, sigma=0.5, min_size=1000)

# %%
regions
# Out:
# [{'labels': [0.0], 'rect': (0, 0, 530, 1079), 'size': 563362},
#  {'labels': [1.0], 'rect': (96, 0, 1823, 1079), 'size': 22652},
#  {'labels': [2.0], 'rect': (535, 0, 844, 240), 'size': 186654},
#  {'labels': [3.0], 'rect': (1379, 0, 540, 199), 'size': 102337},
#  {'labels': [4.0], 'rect': (1375, 191, 544, 888), 'size': 445789},
#  {'labels': [5.0], 'rect': (529, 211, 895, 868), 'size': 716235},
#  {'labels': [6.0], 'rect': (1376, 216, 62, 863), 'size': 11243},
#  {'labels': [7.0], 'rect': (836, 514, 235, 259), 'size': 22736},
#  {'labels': [8.0], 'rect': (817, 551, 41, 217), 'size': 2592},
#  {'labels': [7.0, 8.0], 'rect': (817, 514, 254, 259), 'size': 25328},
#  {'labels': [4.0, 6.0], 'rect': (1375, 191, 544, 888), 'size': 457032},
#  {'labels': [4.0, 6.0, 2.0], 'rect': (535, 0, 1384, 1079), 'size': 643686},
#  {'labels': [0.0, 5.0], 'rect': (0, 0, 1424, 1079), 'size': 1279597},
#  {'labels': [7.0, 8.0, 1.0], 'rect': (96, 0, 1823, 1079), 'size': 47980},
#  {'labels': [0.0, 5.0, 4.0, 6.0, 2.0],
#   'rect': (0, 0, 1919, 1079),
#   'size': 1923283},
#  {'labels': [0.0, 5.0, 4.0, 6.0, 2.0, 7.0, 8.0, 1.0],
#   'rect': (0, 0, 1919, 1079),
#   'size': 1971263},
#  {'labels': [0.0, 5.0, 4.0, 6.0, 2.0, 7.0, 8.0, 1.0, 3.0],
#   'rect': (0, 0, 1919, 1079),
#   'size': 2073600}]

# %%
candidates = set()

# %%
for r in regions:
    if r['rect'] in candidates:
        continue
    if r['size'] < 500000:
        continue
        
    x , y, w, h = r['rect']
    if((w / h) > 1.2 or (h / w) > 1.2):
        continue
        
    candidates.add(r['rect'])

# %%
fig, ax = plt.subplots(ncols=1,nrows=1, figsize=(25,25))
ax.imshow(img)

for x, y, w, h in candidates:
    print(x , y, w, h)
    rect = mpatches.Rectangle((x, y), w, h, fill=False, edgecolor='red', linewidth=1)
    ax.add_patch(rect)
    
plt.show()
# Out:
# 529 211 895 868

# %%
#cv2.imshow()

# %%
plt.imshow(img_lbl)
plt.show()
